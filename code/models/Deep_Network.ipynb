# %%
import sys
sys.path.append('/home/ec2-user/CpGPython/')
import pandas as pd
import numpy as np
import tensorflow as tf
import Logger
from functools import partial
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import f1_score,accuracy_score,recall_score,precision_score,roc_auc_score

# %%
#---------------------------------------------------------------------------
def scores(predicts,y,average='macro'):
    class_num = len(np.unique(y))
    score_map = {}
    if class_num <=2:
        recall = recall_score(y,predicts)      
        precision = precision_score(y,predicts)      
        accuracy = accuracy_score(y,predicts)
        f1 = f1_score(y,predicts)
        auc = roc_auc_score(y,predicts)
        score_map['auc'] = auc
    else:
        recall = recall_score(y,predicts,average=average)      
        precision = precision_score(y,predicts,average=average)      
        accuracy = accuracy_score(y,predicts)
        f1 = f1_score(y,predicts,average=average)
        
    score_map['recall'] = recall
    score_map['precision'] = precision
    score_map['accuracy'] = accuracy
    score_map['f1'] = f1
    return score_map

# %%
home='/home/ec2-user/CpGPython/'
log_dir = home+'logs/'
logger = Logger.Logger(log_dir,False).get_logger()

# %%
##features selecetd by traditional methods
with pd.HDFStore(home+'data/selected_features','r') as h5s:
    train_x =h5s['train_x'] 
    train_label = h5s['train_label'] 
    test_x = h5s['test_x'] 
    test_label = h5s['test_label']   
    sample_weights_train = h5s['sample_weights_train'] 
    sample_weights_test = h5s['sample_weights_test'] 
logger.info('Features used in training are from traditional feature selection')

# %%
n_inputs = train_x.shape[1]
n_hidden1= n_inputs*2
n_hidden2 = int(n_inputs*1)
n_hidden3 = int(n_inputs*0.5)
n_outputs = len(train_label.unique())
l2_reg = 0.1
dropout_rate = 0.5
train_x = MinMaxScaler(copy=True,feature_range=(0,1)).fit_transform(train_x)
test_x = MinMaxScaler().fit_transform(test_x)

# %%
inputs = tf.placeholder(tf.float32,shape=(None,n_inputs),name='inputs')
sample_weights = tf.placeholder(tf.float32,shape=(None),name='weights')
targets = tf.placeholder(tf.float32,shape=(None),name='targets')
training = tf.placeholder_with_default(False,shape=(),name='training')
activation = tf.nn.elu
he_init = tf.contrib.layers.variance_scaling_initializer()
regularizer = tf.contrib.layers.l2_regularizer(l2_reg)
dense_layer = partial(tf.layers.dense,kernel_regularizer=regularizer,kernel_initializer=he_init)
dropout = partial(tf.layers.dropout,rate=dropout_rate,training=training)
batch_norm = partial(tf.layers.batch_normalization,training=training,momentum=0.9)

# %%
with tf.name_scope('dnn'):
    input_drop = dropout(inputs,name='dropout_input')
    hidden1 = dense_layer(input_drop,n_hidden1,name='hidden1')
    bn1 = batch_norm(hidden1,name='batch_norm1')
    bn1_act = activation(bn1,name='batch_norm_act1')
    hidden1_drop = dropout(bn1_act,name='dropout1')
    
    hidden2 = dense_layer(hidden1_drop,n_hidden2,name='hidden2')
    bn2 = batch_norm(hidden2,name='batch_norm2')
    bn2_act = activation(bn2,name='batch_norm_act2')
    hidden2_drop = dropout(bn2_act,name='dropout2')
    
    hidden3 = dense_layer(hidden2_drop,n_hidden3,name='hidden3')
    bn3 = batch_norm(hidden3,name='batch_norm3')
    bn3_act = activation(bn3,name='batch_norm_act3')
    hidden3_drop = dropout(bn3_act,name='dropout3')
    
    logits_before_bn = dense_layer(hidden3_drop,n_outputs,name='logits_before_bn')
    logits = batch_norm(logits_before_bn,name='logits')

# %%
with tf.name_scope('loss'):
    reg_loss = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    base_loss = tf.reduce_mean(tf.nn.weighted_cross_entropy_with_logits(targets=targets,
                                                                        logits=logits,pos_weight=sample_weights),name='base_loss')
    loss = tf.add_n([base_loss]+reg_loss,name='loss')

# %%
with tf.name_scope('train'):
    optimizer = tf.train.AdadeltaOptimizer()
    training_op =optimizer.minimize(loss)

# %%
with tf.name_scope('eval'):
    pred = tf.argmax(logits,1)

# %%
init = tf.global_variables_initializer()
n_epochs = 200
n_batch = 30
batch_size = train_x.shape[0]//n_batch
logger.info('Training epochs: %d, training batches: %d, batch_size: %d',n_epochs,n_batch,batch_size)
saver = tf.train.Saver() 
sample_weights_train.reset_index(drop=True,inplace=True)
train_label.reset_index(drop=True,inplace=True)
sample_weights_test.reset_index(drop=True,inplace=True)
test_label.reset_index(drop=True,inplace=True)
update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)

# %%
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        random_ix = np.random.permutation(train_x.shape[0]) 
        for iteration in range(n_batch):
            start_ix = iteration*batch_size 
            end_ix = np.minimum((iteration+1)*batch_size,train_x.shape[0])
            ixs = random_ix[start_ix:end_ix]
            x_batch = train_x[ixs,:]
            weights_batch = sample_weights_train[ixs].values.reshape([-1,1])
            y_batch = train_label[ixs].values.reshape([-1,1])
            if iteration == 15:
                pred_results,losses = sess.run([pred,loss],feed_dict={inputs:x_batch,sample_weights:weights_batch,training:True,targets:y_batch})
                score_maps = scores(pred_results,y_batch)
                print("At epoch"+str(epoch)+" loss: "+str(losses)+"\n"+str(score_maps))
            # print(hidden1_mean.eval(feed_dict={inputs:x_batch,sample_weights:weights_batch,training:True}))
            sess.run([training_op,update_ops],feed_dict={inputs:x_batch,sample_weights:weights_batch,training:True,targets:y_batch})    
    pred_results,losses = sess.run([pred,loss],feed_dict={inputs:x_batch,sample_weights:weights_batch,training:True,targets:y_batch})
    score_maps = scores(pred_results,y_batch)
    print("At the end loss: "+str(losses)+"\n"+str(score_maps))
#    total_x = np.concatenate([np.array(train_x),np.array(test_x)])
#    total_label = np.concatenate([np.array(train_label),np.array(test_label)])
#    total_weights = pd.concat([sample_weights_train,sample_weights_test],ignore_index=True).values.reshape((-1,1))
    test_weights = sample_weights_test.values.reshape([-1,1])
    test_labels = test_label.values.reshape([-1,1])
    test_preds = pred.eval(feed_dict={inputs:test_x,sample_weights:test_weights,targets:test_labels})    
    test_score_maps = scores(test_preds,test_labels)
    saver.save(sess,'/home/ec2-user/tensor_model/deep_network.ckpt') 
    logger.info('Test scores: \n'+str(test_score_maps))
# Out:
# At epoch0 loss: 63.761467
# {'auc': 0.6088709677419355, 'recall': 0.75, 'precision': 0.15384615384615385, 'accuracy': 0.5, 'f1': 0.25531914893617025}
# target shape is <unknown> logits shape is (?, 2)
# At epoch1 loss: 63.71978
# {'auc': 0.3177083333333333, 'recall': 0.16666666666666666, 'precision': 0.02857142857142857, 'accuracy': 0.44285714285714284, 'f1': 0.048780487804878044}
# target shape is <unknown> logits shape is (?, 2)
# At epoch2 loss: 63.632065
# {'auc': 0.7063492063492064, 'recall': 0.8571428571428571, 'precision': 0.17647058823529413, 'accuracy': 0.5857142857142857, 'f1': 0.29268292682926833}
# target shape is <unknown> logits shape is (?, 2)
# At epoch3 loss: 63.77637
# {'auc': 0.35080645161290325, 'recall': 0.25, 'precision': 0.05555555555555555, 'accuracy': 0.42857142857142855, 'f1': 0.0909090909090909}
# target shape is <unknown> logits shape is (?, 2)
# At epoch4 loss: 63.766075
# {'auc': 0.47580645161290325, 'recall': 0.5, 'precision': 0.10526315789473684, 'accuracy': 0.45714285714285713, 'f1': 0.17391304347826086}
# target shape is <unknown> logits shape is (?, 2)
# At epoch5 loss: 63.598118
# {'auc': 0.5, 'recall': 0.5, 'precision': 0.08571428571428572, 'accuracy': 0.5, 'f1': 0.14634146341463414}
# target shape is <unknown> logits shape is (?, 2)
# At epoch6 loss: 63.56663
# {'auc': 0.7352941176470589, 'recall': 1.0, 'precision': 0.05263157894736842, 'accuracy': 0.4857142857142857, 'f1': 0.1}
# target shape is <unknown> logits shape is (?, 2)
# At epoch7 loss: 63.68669
# {'auc': 0.5317460317460317, 'recall': 0.5714285714285714, 'precision': 0.1111111111111111, 'accuracy': 0.5, 'f1': 0.18604651162790697}
# target shape is <unknown> logits shape is (?, 2)
# At epoch8 loss: 63.64561
# {'auc': 0.5416666666666666, 'recall': 0.6, 'precision': 0.16216216216216217, 'accuracy': 0.5, 'f1': 0.25531914893617025}
# target shape is <unknown> logits shape is (?, 2)
# At epoch9 loss: 63.58541
# {'auc': 0.4927140255009107, 'recall': 0.4444444444444444, 'precision': 0.125, 'accuracy': 0.5285714285714286, 'f1': 0.1951219512195122}
# target shape is <unknown> logits shape is (?, 2)
# At epoch10 loss: 63.582886
# {'auc': 0.30443548387096775, 'recall': 0.125, 'precision': 0.030303030303030304, 'accuracy': 0.44285714285714284, 'f1': 0.04878048780487805}
# target shape is <unknown> logits shape is (?, 2)
# At epoch11 loss: 63.544563
# {'auc': 0.44556451612903225, 'recall': 0.375, 'precision': 0.09090909090909091, 'accuracy': 0.5, 'f1': 0.14634146341463414}
# target shape is <unknown> logits shape is (?, 2)
# At epoch12 loss: 63.49669
# {'auc': 0.20454545454545453, 'recall': 0.0, 'precision': 0.0, 'accuracy': 0.38571428571428573, 'f1': 0.0}
# target shape is <unknown> logits shape is (?, 2)
# At epoch13 loss: 63.47146
# {'auc': 0.5, 'recall': 0.6, 'precision': 0.07142857142857142, 'accuracy': 0.4142857142857143, 'f1': 0.1276595744680851}
# target shape is <unknown> logits shape is (?, 2)
# At epoch14 loss: 63.373074
# {'auc': 0.7720588235294118, 'recall': 1.0, 'precision': 0.06060606060606061, 'accuracy': 0.5571428571428572, 'f1': 0.1142857142857143}
# target shape is <unknown> logits shape is (?, 2)
# At epoch15 loss: 63.388874
# {'auc': 0.5303030303030303, 'recall': 0.5, 'precision': 0.06451612903225806, 'accuracy': 0.5571428571428572, 'f1': 0.1142857142857143}
# target shape is <unknown> logits shape is (?, 2)
# At epoch16 loss: 63.522076
# {'auc': 0.5755208333333333, 'recall': 0.6666666666666666, 'precision': 0.10810810810810811, 'accuracy': 0.5, 'f1': 0.18604651162790697}
# target shape is <unknown> logits shape is (?, 2)
# At epoch17 loss: 63.42501
# {'auc': 0.40476190476190477, 'recall': 0.2857142857142857, 'precision': 0.0625, 'accuracy': 0.5, 'f1': 0.10256410256410256}
# target shape is <unknown> logits shape is (?, 2)
# At epoch18 loss: 63.39075
# {'auc': 0.5, 'recall': 0.5, 'precision': 0.05714285714285714, 'accuracy': 0.5, 'f1': 0.10256410256410256}
# target shape is <unknown> logits shape is (?, 2)
# At epoch19 loss: 63.44671
# {'auc': 0.5463709677419355, 'recall': 0.625, 'precision': 0.13157894736842105, 'accuracy': 0.4857142857142857, 'f1': 0.21739130434782608}
# target shape is <unknown> logits shape is (?, 2)
# At epoch20 loss: 63.52217
# {'auc': 0.3961748633879781, 'recall': 0.3333333333333333, 'precision': 0.08333333333333333, 'accuracy': 0.44285714285714284, 'f1': 0.13333333333333333}
# target shape is <unknown> logits shape is (?, 2)
# At epoch21 loss: 63.344368
# {'auc': 0.4166666666666667, 'recall': 0.4, 'precision': 0.10526315789473684, 'accuracy': 0.42857142857142855, 'f1': 0.16666666666666666}
# target shape is <unknown> logits shape is (?, 2)
# At epoch22 loss: 63.41133
# {'auc': 0.3522727272727273, 'recall': 0.25, 'precision': 0.02702702702702703, 'accuracy': 0.44285714285714284, 'f1': 0.04878048780487805}
# target shape is <unknown> logits shape is (?, 2)
# At epoch23 loss: 63.301178
# {'auc': 0.515625, 'recall': 0.5, 'precision': 0.09090909090909091, 'accuracy': 0.5285714285714286, 'f1': 0.15384615384615385}
# target shape is <unknown> logits shape is (?, 2)
# At epoch24 loss: 63.25854
# {'auc': 0.3384615384615385, 'recall': 0.2, 'precision': 0.02857142857142857, 'accuracy': 0.45714285714285713, 'f1': 0.049999999999999996}
# target shape is <unknown> logits shape is (?, 2)
# At epoch25 loss: 63.14375
# {'auc': 0.4779411764705882, 'recall': 0.5, 'precision': 0.02631578947368421, 'accuracy': 0.45714285714285713, 'f1': 0.05}
# target shape is <unknown> logits shape is (?, 2)
# At epoch26 loss: 63.441025
# {'auc': 0.5100154083204931, 'recall': 0.5454545454545454, 'precision': 0.16216216216216217, 'accuracy': 0.4857142857142857, 'f1': 0.25}
# target shape is <unknown> logits shape is (?, 2)
# At epoch27 loss: 63.355247
# {'auc': 0.32661290322580644, 'recall': 0.25, 'precision': 0.05128205128205128, 'accuracy': 0.38571428571428573, 'f1': 0.0851063829787234}
# target shape is <unknown> logits shape is (?, 2)
# At epoch28 loss: 63.295956
# {'auc': 0.3588709677419355, 'recall': 0.25, 'precision': 0.05714285714285714, 'accuracy': 0.44285714285714284, 'f1': 0.09302325581395347}
# target shape is <unknown> logits shape is (?, 2)
# At epoch29 loss: 63.276474
# {'auc': 0.373015873015873, 'recall': 0.2857142857142857, 'precision': 0.05555555555555555, 'accuracy': 0.44285714285714284, 'f1': 0.09302325581395349}
# target shape is <unknown> logits shape is (?, 2)
# At epoch30 loss: 63.098515
# {'auc': 0.6243781094527363, 'recall': 0.6666666666666666, 'precision': 0.06666666666666667, 'accuracy': 0.5857142857142857, 'f1': 0.1212121212121212}
# target shape is <unknown> logits shape is (?, 2)
# At epoch31 loss: 63.166557
# {'auc': 0.37760416666666663, 'recall': 0.3333333333333333, 'precision': 0.05128205128205128, 'accuracy': 0.4142857142857143, 'f1': 0.08888888888888889}
# target shape is <unknown> logits shape is (?, 2)
# At epoch32 loss: 63.302784
# {'auc': 0.5154826958105647, 'recall': 0.5555555555555556, 'precision': 0.13513513513513514, 'accuracy': 0.4857142857142857, 'f1': 0.2173913043478261}
# target shape is <unknown> logits shape is (?, 2)
# At epoch33 loss: 63.175583
# {'auc': 0.6, 'recall': 0.7, 'precision': 0.1891891891891892, 'accuracy': 0.5285714285714286, 'f1': 0.2978723404255319}
# target shape is <unknown> logits shape is (?, 2)
# At epoch34 loss: 63.06038
# {'auc': 0.34895833333333337, 'recall': 0.16666666666666666, 'precision': 0.03225806451612903, 'accuracy': 0.5, 'f1': 0.05405405405405405}
# target shape is <unknown> logits shape is (?, 2)
# At epoch35 loss: 63.182407
# {'auc': 0.4663023679417122, 'recall': 0.5555555555555556, 'precision': 0.11627906976744186, 'accuracy': 0.4, 'f1': 0.19230769230769232}
# target shape is <unknown> logits shape is (?, 2)
# At epoch36 loss: 63.1244
# {'auc': 0.42943548387096775, 'recall': 0.375, 'precision': 0.08571428571428572, 'accuracy': 0.4714285714285714, 'f1': 0.1395348837209302}
# target shape is <unknown> logits shape is (?, 2)
# At epoch37 loss: 62.9271
# {'auc': 0.5870646766169154, 'recall': 0.6666666666666666, 'precision': 0.05714285714285714, 'accuracy': 0.5142857142857142, 'f1': 0.10526315789473684}
# target shape is <unknown> logits shape is (?, 2)
# At epoch38 loss: 62.94495
# {'auc': 0.40104166666666663, 'recall': 0.3333333333333333, 'precision': 0.05555555555555555, 'accuracy': 0.45714285714285713, 'f1': 0.09523809523809525}
# target shape is <unknown> logits shape is (?, 2)
# At epoch39 loss: 63.06716
# {'auc': 0.4763205828779599, 'recall': 0.4444444444444444, 'precision': 0.11764705882352941, 'accuracy': 0.5, 'f1': 0.18604651162790695}
# target shape is <unknown> logits shape is (?, 2)
# At epoch40 loss: 62.94733
# {'auc': 0.4765625, 'recall': 0.5, 'precision': 0.07894736842105263, 'accuracy': 0.45714285714285713, 'f1': 0.13636363636363635}
# target shape is <unknown> logits shape is (?, 2)
# At epoch41 loss: 63.010883
# {'auc': 0.30000000000000004, 'recall': 0.1, 'precision': 0.03225806451612903, 'accuracy': 0.44285714285714284, 'f1': 0.04878048780487805}
# target shape is <unknown> logits shape is (?, 2)
# At epoch42 loss: 62.9282
# {'auc': 0.5476190476190477, 'recall': 0.5714285714285714, 'precision': 0.11764705882352941, 'accuracy': 0.5285714285714286, 'f1': 0.1951219512195122}
# target shape is <unknown> logits shape is (?, 2)
# At epoch43 loss: 62.92387
# {'auc': 0.5, 'recall': 0.5, 'precision': 0.08571428571428572, 'accuracy': 0.5, 'f1': 0.14634146341463414}
# target shape is <unknown> logits shape is (?, 2)
# At epoch44 loss: 62.85887
# {'auc': 0.6588541666666667, 'recall': 0.8333333333333334, 'precision': 0.13157894736842105, 'accuracy': 0.5142857142857142, 'f1': 0.22727272727272727}
# target shape is <unknown> logits shape is (?, 2)
# At epoch45 loss: 62.919376
# {'auc': 0.5677083333333333, 'recall': 0.6666666666666666, 'precision': 0.10526315789473684, 'accuracy': 0.4857142857142857, 'f1': 0.18181818181818182}
# target shape is <unknown> logits shape is (?, 2)
# At epoch46 loss: 62.859432
# {'auc': 0.5161290322580645, 'recall': 0.5, 'precision': 0.12121212121212122, 'accuracy': 0.5285714285714286, 'f1': 0.1951219512195122}
# target shape is <unknown> logits shape is (?, 2)
# At epoch47 loss: 62.786366
# {'auc': 0.37760416666666663, 'recall': 0.3333333333333333, 'precision': 0.05128205128205128, 'accuracy': 0.4142857142857143, 'f1': 0.08888888888888889}
# target shape is <unknown> logits shape is (?, 2)
# At epoch48 loss: 62.835884
# {'auc': 0.45173041894353366, 'recall': 0.4444444444444444, 'precision': 0.10810810810810811, 'accuracy': 0.45714285714285713, 'f1': 0.17391304347826086}
# target shape is <unknown> logits shape is (?, 2)
# At epoch49 loss: 62.74155
# {'auc': 0.3153846153846154, 'recall': 0.2, 'precision': 0.02631578947368421, 'accuracy': 0.4142857142857143, 'f1': 0.046511627906976744}
# target shape is <unknown> logits shape is (?, 2)
# At epoch50 loss: 62.753475
# {'auc': 0.2936507936507936, 'recall': 0.14285714285714285, 'precision': 0.027777777777777776, 'accuracy': 0.4142857142857143, 'f1': 0.046511627906976744}
# target shape is <unknown> logits shape is (?, 2)
# At epoch51 loss: 62.895367
# {'auc': 0.5705645161290323, 'recall': 0.625, 'precision': 0.14285714285714285, 'accuracy': 0.5285714285714286, 'f1': 0.23255813953488372}
# target shape is <unknown> logits shape is (?, 2)
# At epoch52 loss: 62.798325
# {'auc': 0.49193548387096775, 'recall': 0.5, 'precision': 0.1111111111111111, 'accuracy': 0.4857142857142857, 'f1': 0.1818181818181818}
# target shape is <unknown> logits shape is (?, 2)
# At epoch53 loss: 62.84423
# {'auc': 0.5384615384615384, 'recall': 0.6, 'precision': 0.08108108108108109, 'accuracy': 0.4857142857142857, 'f1': 0.14285714285714288}
# target shape is <unknown> logits shape is (?, 2)
# At epoch54 loss: 62.526447
# {'auc': 0.4696969696969697, 'recall': 0.5, 'precision': 0.05128205128205128, 'accuracy': 0.44285714285714284, 'f1': 0.09302325581395347}
# target shape is <unknown> logits shape is (?, 2)
# At epoch55 loss: 62.64347
# {'auc': 0.41269841269841273, 'recall': 0.42857142857142855, 'precision': 0.07317073170731707, 'accuracy': 0.4, 'f1': 0.125}
# target shape is <unknown> logits shape is (?, 2)
# At epoch56 loss: 62.628323
# {'auc': 0.3522727272727273, 'recall': 0.25, 'precision': 0.02702702702702703, 'accuracy': 0.44285714285714284, 'f1': 0.04878048780487805}
# target shape is <unknown> logits shape is (?, 2)
# At epoch57 loss: 62.574554
# {'auc': 0.6901041666666667, 'recall': 0.8333333333333334, 'precision': 0.14705882352941177, 'accuracy': 0.5714285714285714, 'f1': 0.25}
# target shape is <unknown> logits shape is (?, 2)
# At epoch58 loss: 62.4332
# {'auc': 0.25, 'recall': 0.0, 'precision': 0.0, 'accuracy': 0.4857142857142857, 'f1': 0.0}
# target shape is <unknown> logits shape is (?, 2)
# At epoch59 loss: 62.53945
# {'auc': 0.6307692307692307, 'recall': 0.8, 'precision': 0.10256410256410256, 'accuracy': 0.4857142857142857, 'f1': 0.18181818181818182}
# target shape is <unknown> logits shape is (?, 2)
# At epoch60 loss: 62.60962
# {'auc': 0.42447916666666663, 'recall': 0.3333333333333333, 'precision': 0.06060606060606061, 'accuracy': 0.5, 'f1': 0.10256410256410256}
# target shape is <unknown> logits shape is (?, 2)
# At epoch61 loss: 62.525158
# {'auc': 0.4916666666666666, 'recall': 0.5, 'precision': 0.1388888888888889, 'accuracy': 0.4857142857142857, 'f1': 0.2173913043478261}
# target shape is <unknown> logits shape is (?, 2)
# At epoch62 loss: 62.49071
# {'auc': 0.703125, 'recall': 1.0, 'precision': 0.13636363636363635, 'accuracy': 0.45714285714285713, 'f1': 0.24000000000000002}
# target shape is <unknown> logits shape is (?, 2)
# At epoch63 loss: 62.398743
# {'auc': 0.4384615384615384, 'recall': 0.4, 'precision': 0.05555555555555555, 'accuracy': 0.4714285714285714, 'f1': 0.09756097560975609}
# target shape is <unknown> logits shape is (?, 2)
# At epoch64 loss: 62.39861
# {'auc': 0.5677083333333333, 'recall': 0.6666666666666666, 'precision': 0.10526315789473684, 'accuracy': 0.4857142857142857, 'f1': 0.18181818181818182}
# target shape is <unknown> logits shape is (?, 2)
# At epoch65 loss: 62.363075
# {'auc': 0.46031746031746035, 'recall': 0.42857142857142855, 'precision': 0.08571428571428572, 'accuracy': 0.4857142857142857, 'f1': 0.14285714285714285}
# target shape is <unknown> logits shape is (?, 2)
# At epoch66 loss: 62.513218
# {'auc': 0.5747126436781609, 'recall': 0.6666666666666666, 'precision': 0.21052631578947367, 'accuracy': 0.5142857142857142, 'f1': 0.32}
# target shape is <unknown> logits shape is (?, 2)
# At epoch67 loss: 62.47474
# {'auc': 0.5357142857142857, 'recall': 0.5714285714285714, 'precision': 0.2222222222222222, 'accuracy': 0.5142857142857142, 'f1': 0.32}
# target shape is <unknown> logits shape is (?, 2)
# At epoch68 loss: 62.32628
# {'auc': 0.4384615384615384, 'recall': 0.4, 'precision': 0.05555555555555555, 'accuracy': 0.4714285714285714, 'f1': 0.09756097560975609}
# target shape is <unknown> logits shape is (?, 2)
# At epoch69 loss: 62.257164
# {'auc': 0.6307692307692307, 'recall': 0.8, 'precision': 0.10256410256410256, 'accuracy': 0.4857142857142857, 'f1': 0.18181818181818182}
# target shape is <unknown> logits shape is (?, 2)
# At epoch70 loss: 62.34204
# {'auc': 0.372983870967742, 'recall': 0.375, 'precision': 0.07142857142857142, 'accuracy': 0.37142857142857144, 'f1': 0.12}
# target shape is <unknown> logits shape is (?, 2)
# At epoch71 loss: 62.237
# {'auc': 0.5463709677419355, 'recall': 0.625, 'precision': 0.13157894736842105, 'accuracy': 0.4857142857142857, 'f1': 0.21739130434782608}
# target shape is <unknown> logits shape is (?, 2)
# At epoch72 loss: 62.160015
# {'auc': 0.390547263681592, 'recall': 0.3333333333333333, 'precision': 0.02631578947368421, 'accuracy': 0.44285714285714284, 'f1': 0.048780487804878044}
# target shape is <unknown> logits shape is (?, 2)
# At epoch73 loss: 62.22476
# {'auc': 0.4765625, 'recall': 0.5, 'precision': 0.07894736842105263, 'accuracy': 0.45714285714285713, 'f1': 0.13636363636363635}
# target shape is <unknown> logits shape is (?, 2)
# At epoch74 loss: 62.182472
# {'auc': 0.32552083333333337, 'recall': 0.16666666666666666, 'precision': 0.029411764705882353, 'accuracy': 0.45714285714285713, 'f1': 0.05}
# target shape is <unknown> logits shape is (?, 2)
# At epoch75 loss: 62.052345
# {'auc': 0.46153846153846145, 'recall': 0.4, 'precision': 0.06060606060606061, 'accuracy': 0.5142857142857142, 'f1': 0.10526315789473685}
# target shape is <unknown> logits shape is (?, 2)
# At epoch76 loss: 61.97425
# {'auc': 0.2391304347826087, 'recall': 0.0, 'precision': 0.0, 'accuracy': 0.4714285714285714, 'f1': 0.0}
# target shape is <unknown> logits shape is (?, 2)
# At epoch77 loss: 62.166576
# {'auc': 0.4676113360323887, 'recall': 0.46153846153846156, 'precision': 0.16666666666666666, 'accuracy': 0.4714285714285714, 'f1': 0.2448979591836735}
# target shape is <unknown> logits shape is (?, 2)
# At epoch78 loss: 62.158096
# {'auc': 0.42447916666666663, 'recall': 0.3333333333333333, 'precision': 0.06060606060606061, 'accuracy': 0.5, 'f1': 0.10256410256410256}
# target shape is <unknown> logits shape is (?, 2)
# At epoch79 loss: 62.056995
# {'auc': 0.6833333333333333, 'recall': 0.8, 'precision': 0.23529411764705882, 'accuracy': 0.6, 'f1': 0.3636363636363636}
# target shape is <unknown> logits shape is (?, 2)
# At epoch80 loss: 62.013157
# {'auc': 0.2272727272727273, 'recall': 0.0, 'precision': 0.0, 'accuracy': 0.42857142857142855, 'f1': 0.0}
# target shape is <unknown> logits shape is (?, 2)
# At epoch81 loss: 61.926544
# {'auc': 0.6510416666666667, 'recall': 0.8333333333333334, 'precision': 0.1282051282051282, 'accuracy': 0.5, 'f1': 0.2222222222222222}
# target shape is <unknown> logits shape is (?, 2)
# At epoch82 loss: 61.93742
# {'auc': 0.46031746031746035, 'recall': 0.42857142857142855, 'precision': 0.08571428571428572, 'accuracy': 0.4857142857142857, 'f1': 0.14285714285714285}
# target shape is <unknown> logits shape is (?, 2)
# At epoch83 loss: 61.992947
# {'auc': 0.44556451612903225, 'recall': 0.375, 'precision': 0.09090909090909091, 'accuracy': 0.5, 'f1': 0.14634146341463414}
# target shape is <unknown> logits shape is (?, 2)
# At epoch84 loss: 61.82651
# {'auc': 0.3153846153846154, 'recall': 0.2, 'precision': 0.02631578947368421, 'accuracy': 0.4142857142857143, 'f1': 0.046511627906976744}
# target shape is <unknown> logits shape is (?, 2)
# At epoch85 loss: 61.851624
# {'auc': 0.5307692307692308, 'recall': 0.6, 'precision': 0.07894736842105263, 'accuracy': 0.4714285714285714, 'f1': 0.1395348837209302}
# target shape is <unknown> logits shape is (?, 2)
# At epoch86 loss: 61.816986
# {'auc': 0.36979166666666663, 'recall': 0.3333333333333333, 'precision': 0.05, 'accuracy': 0.4, 'f1': 0.08695652173913045}
# target shape is <unknown> logits shape is (?, 2)
# At epoch87 loss: 61.804413
# {'auc': 0.4354838709677419, 'recall': 0.5, 'precision': 0.09302325581395349, 'accuracy': 0.38571428571428573, 'f1': 0.15686274509803924}
# target shape is <unknown> logits shape is (?, 2)
# At epoch88 loss: 61.812935
# {'auc': 0.4206349206349206, 'recall': 0.42857142857142855, 'precision': 0.075, 'accuracy': 0.4142857142857143, 'f1': 0.1276595744680851}
# target shape is <unknown> logits shape is (?, 2)
# At epoch89 loss: 61.791786
# {'auc': 0.6615384615384615, 'recall': 0.8, 'precision': 0.11428571428571428, 'accuracy': 0.5428571428571428, 'f1': 0.19999999999999998}
# target shape is <unknown> logits shape is (?, 2)
# At epoch90 loss: 61.754456
# {'auc': 0.5078125, 'recall': 0.5, 'precision': 0.08823529411764706, 'accuracy': 0.5142857142857142, 'f1': 0.15}
# target shape is <unknown> logits shape is (?, 2)
# At epoch91 loss: 61.69545
# {'auc': 0.4416666666666666, 'recall': 0.4, 'precision': 0.11428571428571428, 'accuracy': 0.4714285714285714, 'f1': 0.17777777777777776}
# target shape is <unknown> logits shape is (?, 2)
# At epoch92 loss: 61.852234
# {'auc': 0.4435336976320583, 'recall': 0.4444444444444444, 'precision': 0.10526315789473684, 'accuracy': 0.44285714285714284, 'f1': 0.1702127659574468}
# target shape is <unknown> logits shape is (?, 2)
# At epoch93 loss: 61.61266
# {'auc': 0.41293532338308453, 'recall': 0.3333333333333333, 'precision': 0.02857142857142857, 'accuracy': 0.4857142857142857, 'f1': 0.05263157894736842}
# target shape is <unknown> logits shape is (?, 2)
# At epoch94 loss: 61.54065
# {'auc': 0.7647058823529411, 'recall': 1.0, 'precision': 0.058823529411764705, 'accuracy': 0.5428571428571428, 'f1': 0.1111111111111111}
# target shape is <unknown> logits shape is (?, 2)
# At epoch95 loss: 61.622604
# {'auc': 0.7461538461538462, 'recall': 1.0, 'precision': 0.13157894736842105, 'accuracy': 0.5285714285714286, 'f1': 0.23255813953488372}
# target shape is <unknown> logits shape is (?, 2)
# At epoch96 loss: 61.628593
# {'auc': 0.37760416666666663, 'recall': 0.3333333333333333, 'precision': 0.05128205128205128, 'accuracy': 0.4142857142857143, 'f1': 0.08888888888888889}
# target shape is <unknown> logits shape is (?, 2)
# At epoch97 loss: 61.640095
# {'auc': 0.587431693989071, 'recall': 0.6666666666666666, 'precision': 0.16666666666666666, 'accuracy': 0.5285714285714286, 'f1': 0.26666666666666666}
# target shape is <unknown> logits shape is (?, 2)
# At epoch98 loss: 61.47836
# {'auc': 0.4696969696969697, 'recall': 0.5, 'precision': 0.05128205128205128, 'accuracy': 0.44285714285714284, 'f1': 0.09302325581395347}
# target shape is <unknown> logits shape is (?, 2)
# At epoch99 loss: 61.497456
# {'auc': 0.4523809523809524, 'recall': 0.42857142857142855, 'precision': 0.08333333333333333, 'accuracy': 0.4714285714285714, 'f1': 0.13953488372093023}
# target shape is <unknown> logits shape is (?, 2)
# At epoch100 loss: 61.453857
# {'auc': 0.41666666666666663, 'recall': 0.3333333333333333, 'precision': 0.058823529411764705, 'accuracy': 0.4857142857142857, 'f1': 0.1}
# target shape is <unknown> logits shape is (?, 2)
# At epoch101 loss: 61.43604
# {'auc': 0.5598958333333333, 'recall': 0.6666666666666666, 'precision': 0.10256410256410256, 'accuracy': 0.4714285714285714, 'f1': 0.17777777777777778}
# target shape is <unknown> logits shape is (?, 2)
# At epoch102 loss: 61.445816
# {'auc': 0.4841269841269841, 'recall': 0.5714285714285714, 'precision': 0.09523809523809523, 'accuracy': 0.4142857142857143, 'f1': 0.16326530612244897}
# target shape is <unknown> logits shape is (?, 2)
# At epoch103 loss: 61.39935
# {'auc': 0.4461538461538461, 'recall': 0.4, 'precision': 0.05714285714285714, 'accuracy': 0.4857142857142857, 'f1': 0.09999999999999999}
# target shape is <unknown> logits shape is (?, 2)
# At epoch104 loss: 61.40437
# {'auc': 0.5625, 'recall': 0.625, 'precision': 0.1388888888888889, 'accuracy': 0.5142857142857142, 'f1': 0.2272727272727273}
# target shape is <unknown> logits shape is (?, 2)
# At epoch105 loss: 61.476025
# {'auc': 0.5705645161290323, 'recall': 0.625, 'precision': 0.14285714285714285, 'accuracy': 0.5285714285714286, 'f1': 0.23255813953488372}
# target shape is <unknown> logits shape is (?, 2)
# At epoch106 loss: 61.238995
# {'auc': 0.3830845771144279, 'recall': 0.3333333333333333, 'precision': 0.02564102564102564, 'accuracy': 0.42857142857142855, 'f1': 0.047619047619047616}
# target shape is <unknown> logits shape is (?, 2)
# At epoch107 loss: 61.186844
# {'auc': 0.7318840579710144, 'recall': 1.0, 'precision': 0.02631578947368421, 'accuracy': 0.4714285714285714, 'f1': 0.05128205128205127}
# target shape is <unknown> logits shape is (?, 2)
# At epoch108 loss: 61.19624
# {'auc': 0.25735294117647056, 'recall': 0.0, 'precision': 0.0, 'accuracy': 0.5, 'f1': 0.0}
# target shape is <unknown> logits shape is (?, 2)
# At epoch109 loss: 61.23992
# {'auc': 0.5318761384335156, 'recall': 0.5555555555555556, 'precision': 0.14285714285714285, 'accuracy': 0.5142857142857142, 'f1': 0.22727272727272727}
# target shape is <unknown> logits shape is (?, 2)
# At epoch110 loss: 61.17547
# {'auc': 0.5153846153846154, 'recall': 0.6, 'precision': 0.075, 'accuracy': 0.44285714285714284, 'f1': 0.13333333333333333}
# target shape is <unknown> logits shape is (?, 2)
# At epoch111 loss: 61.129852
# {'auc': 0.375, 'recall': 0.25, 'precision': 0.029411764705882353, 'accuracy': 0.4857142857142857, 'f1': 0.05263157894736842}
# target shape is <unknown> logits shape is (?, 2)
# At epoch112 loss: 61.06048
# {'auc': 0.4558823529411765, 'recall': 0.5, 'precision': 0.024390243902439025, 'accuracy': 0.4142857142857143, 'f1': 0.046511627906976744}
# target shape is <unknown> logits shape is (?, 2)
# At epoch113 loss: 61.1179
# {'auc': 0.5461538461538462, 'recall': 0.6, 'precision': 0.08333333333333333, 'accuracy': 0.5, 'f1': 0.14634146341463414}
# target shape is <unknown> logits shape is (?, 2)
# At epoch114 loss: 61.056004
# {'auc': 0.41293532338308453, 'recall': 0.3333333333333333, 'precision': 0.02857142857142857, 'accuracy': 0.4857142857142857, 'f1': 0.05263157894736842}
# target shape is <unknown> logits shape is (?, 2)
# At epoch115 loss: 61.162735
# {'auc': 0.4838709677419355, 'recall': 0.5, 'precision': 0.10810810810810811, 'accuracy': 0.4714285714285714, 'f1': 0.17777777777777778}
# target shape is <unknown> logits shape is (?, 2)
# At epoch116 loss: 61.00374
# {'auc': 0.625, 'recall': 0.75, 'precision': 0.08333333333333333, 'accuracy': 0.5142857142857142, 'f1': 0.15}
# target shape is <unknown> logits shape is (?, 2)
# At epoch117 loss: 61.02244
# {'auc': 0.2615384615384615, 'recall': 0.0, 'precision': 0.0, 'accuracy': 0.4857142857142857, 'f1': 0.0}
# target shape is <unknown> logits shape is (?, 2)
# At epoch118 loss: 60.9146
# {'auc': 0.5227272727272727, 'recall': 0.5, 'precision': 0.0625, 'accuracy': 0.5428571428571428, 'f1': 0.1111111111111111}
# target shape is <unknown> logits shape is (?, 2)
# At epoch119 loss: 61.021942
# {'auc': 0.42857142857142855, 'recall': 0.42857142857142855, 'precision': 0.07692307692307693, 'accuracy': 0.42857142857142855, 'f1': 0.13043478260869565}
# target shape is <unknown> logits shape is (?, 2)
# At epoch120 loss: 60.97321
# {'auc': 0.484375, 'recall': 0.5, 'precision': 0.08108108108108109, 'accuracy': 0.4714285714285714, 'f1': 0.13953488372093023}
# target shape is <unknown> logits shape is (?, 2)
# At epoch121 loss: 60.880226
# {'auc': 0.49242424242424243, 'recall': 0.5, 'precision': 0.05555555555555555, 'accuracy': 0.4857142857142857, 'f1': 0.09999999999999999}
# target shape is <unknown> logits shape is (?, 2)
# At epoch122 loss: 60.955154
# {'auc': 0.3538461538461538, 'recall': 0.2, 'precision': 0.030303030303030304, 'accuracy': 0.4857142857142857, 'f1': 0.052631578947368425}
# target shape is <unknown> logits shape is (?, 2)
# At epoch123 loss: 60.717922
# {'auc': 0.24637681159420288, 'recall': 0.0, 'precision': 0.0, 'accuracy': 0.4857142857142857, 'f1': 0.0}
# target shape is <unknown> logits shape is (?, 2)
# At epoch124 loss: 60.945103
# {'auc': 0.5083333333333333, 'recall': 0.5, 'precision': 0.14705882352941177, 'accuracy': 0.5142857142857142, 'f1': 0.22727272727272727}
# target shape is <unknown> logits shape is (?, 2)
# At epoch125 loss: 60.879322
# {'auc': 0.524425287356322, 'recall': 0.5833333333333334, 'precision': 0.18421052631578946, 'accuracy': 0.4857142857142857, 'f1': 0.27999999999999997}
# target shape is <unknown> logits shape is (?, 2)
# At epoch126 loss: 60.942356
# {'auc': 0.45546558704453444, 'recall': 0.38461538461538464, 'precision': 0.15625, 'accuracy': 0.5, 'f1': 0.22222222222222224}
# target shape is <unknown> logits shape is (?, 2)
# At epoch127 loss: 60.829273
# {'auc': 0.47580645161290325, 'recall': 0.5, 'precision': 0.10526315789473684, 'accuracy': 0.45714285714285713, 'f1': 0.17391304347826086}
# target shape is <unknown> logits shape is (?, 2)
# At epoch128 loss: 60.71836
# {'auc': 0.5685483870967742, 'recall': 0.75, 'precision': 0.13636363636363635, 'accuracy': 0.42857142857142855, 'f1': 0.23076923076923075}
# target shape is <unknown> logits shape is (?, 2)
# At epoch129 loss: 60.616142
# {'auc': 0.625, 'recall': 0.75, 'precision': 0.08333333333333333, 'accuracy': 0.5142857142857142, 'f1': 0.15}
# target shape is <unknown> logits shape is (?, 2)
# At epoch130 loss: 60.618244
# {'auc': 0.36742424242424243, 'recall': 0.25, 'precision': 0.02857142857142857, 'accuracy': 0.4714285714285714, 'f1': 0.05128205128205128}
# target shape is <unknown> logits shape is (?, 2)
# At epoch131 loss: 60.794186
# {'auc': 0.2988505747126437, 'recall': 0.16666666666666666, 'precision': 0.05714285714285714, 'accuracy': 0.38571428571428573, 'f1': 0.0851063829787234}
# target shape is <unknown> logits shape is (?, 2)
# At epoch132 loss: 60.573757
# {'auc': 0.5786290322580645, 'recall': 0.625, 'precision': 0.14705882352941177, 'accuracy': 0.5428571428571428, 'f1': 0.2380952380952381}
# target shape is <unknown> logits shape is (?, 2)
# At epoch133 loss: 60.66908
# {'auc': 0.6083333333333333, 'recall': 0.7, 'precision': 0.19444444444444445, 'accuracy': 0.5428571428571428, 'f1': 0.30434782608695654}
# target shape is <unknown> logits shape is (?, 2)
# At epoch134 loss: 60.554935
# {'auc': 0.39322916666666663, 'recall': 0.3333333333333333, 'precision': 0.05405405405405406, 'accuracy': 0.44285714285714284, 'f1': 0.09302325581395349}
# target shape is <unknown> logits shape is (?, 2)
# At epoch135 loss: 60.493443
# {'auc': 0.4765625, 'recall': 0.5, 'precision': 0.07894736842105263, 'accuracy': 0.45714285714285713, 'f1': 0.13636363636363635}
# target shape is <unknown> logits shape is (?, 2)
# At epoch136 loss: 60.477154
# {'auc': 0.6615384615384615, 'recall': 0.8, 'precision': 0.11428571428571428, 'accuracy': 0.5428571428571428, 'f1': 0.19999999999999998}
# target shape is <unknown> logits shape is (?, 2)
# At epoch137 loss: 60.359657
# {'auc': 0.5870646766169154, 'recall': 0.6666666666666666, 'precision': 0.05714285714285714, 'accuracy': 0.5142857142857142, 'f1': 0.10526315789473684}
# target shape is <unknown> logits shape is (?, 2)
# At epoch138 loss: 60.303448
# {'auc': 0.19402985074626866, 'recall': 0.0, 'precision': 0.0, 'accuracy': 0.37142857142857144, 'f1': 0.0}
# target shape is <unknown> logits shape is (?, 2)
# At epoch139 loss: 60.355206
# {'auc': 0.46031746031746035, 'recall': 0.42857142857142855, 'precision': 0.08571428571428572, 'accuracy': 0.4857142857142857, 'f1': 0.14285714285714285}
# target shape is <unknown> logits shape is (?, 2)
# At epoch140 loss: 60.35058
# {'auc': 0.5911458333333333, 'recall': 0.6666666666666666, 'precision': 0.11428571428571428, 'accuracy': 0.5285714285714286, 'f1': 0.19512195121951217}
# target shape is <unknown> logits shape is (?, 2)
# At epoch141 loss: 60.275917
# {'auc': 0.4444444444444444, 'recall': 0.42857142857142855, 'precision': 0.08108108108108109, 'accuracy': 0.45714285714285713, 'f1': 0.13636363636363638}
# target shape is <unknown> logits shape is (?, 2)
# At epoch142 loss: 60.248215
# {'auc': 0.3538461538461538, 'recall': 0.2, 'precision': 0.030303030303030304, 'accuracy': 0.4857142857142857, 'f1': 0.052631578947368425}
# target shape is <unknown> logits shape is (?, 2)
# At epoch143 loss: 60.23382
# {'auc': 0.5238095238095237, 'recall': 0.5714285714285714, 'precision': 0.10810810810810811, 'accuracy': 0.4857142857142857, 'f1': 0.18181818181818182}
# target shape is <unknown> logits shape is (?, 2)
# At epoch144 loss: 60.30993
# {'auc': 0.405241935483871, 'recall': 0.375, 'precision': 0.07894736842105263, 'accuracy': 0.42857142857142855, 'f1': 0.13043478260869565}
# target shape is <unknown> logits shape is (?, 2)
# At epoch145 loss: 60.448307
# {'auc': 0.5330459770114943, 'recall': 0.5833333333333334, 'precision': 0.1891891891891892, 'accuracy': 0.5, 'f1': 0.28571428571428575}
# target shape is <unknown> logits shape is (?, 2)
# At epoch146 loss: 60.11902
# {'auc': 0.5520833333333333, 'recall': 0.6666666666666666, 'precision': 0.1, 'accuracy': 0.45714285714285713, 'f1': 0.1739130434782609}
# target shape is <unknown> logits shape is (?, 2)
# At epoch147 loss: 60.205967
# {'auc': 0.373015873015873, 'recall': 0.2857142857142857, 'precision': 0.05555555555555555, 'accuracy': 0.44285714285714284, 'f1': 0.09302325581395349}
# target shape is <unknown> logits shape is (?, 2)
# At epoch148 loss: 60.031315
# {'auc': 0.5307692307692308, 'recall': 0.6, 'precision': 0.07894736842105263, 'accuracy': 0.4714285714285714, 'f1': 0.1395348837209302}
# target shape is <unknown> logits shape is (?, 2)
# At epoch149 loss: 60.02962
# {'auc': 0.3830845771144279, 'recall': 0.3333333333333333, 'precision': 0.02564102564102564, 'accuracy': 0.42857142857142855, 'f1': 0.047619047619047616}
# target shape is <unknown> logits shape is (?, 2)
# At epoch150 loss: 59.96813
# {'auc': 0.5796019900497512, 'recall': 0.6666666666666666, 'precision': 0.05555555555555555, 'accuracy': 0.5, 'f1': 0.10256410256410256}
# target shape is <unknown> logits shape is (?, 2)
# At epoch151 loss: 59.984703
# {'auc': 0.40885416666666663, 'recall': 0.3333333333333333, 'precision': 0.05714285714285714, 'accuracy': 0.4714285714285714, 'f1': 0.09756097560975609}
# target shape is <unknown> logits shape is (?, 2)
# At epoch152 loss: 59.966682
# {'auc': 0.3153846153846154, 'recall': 0.2, 'precision': 0.02631578947368421, 'accuracy': 0.4142857142857143, 'f1': 0.046511627906976744}
# target shape is <unknown> logits shape is (?, 2)
# At epoch153 loss: 60.02225
# {'auc': 0.5461538461538462, 'recall': 0.6, 'precision': 0.08333333333333333, 'accuracy': 0.5, 'f1': 0.14634146341463414}
# target shape is <unknown> logits shape is (?, 2)
# At epoch154 loss: 59.897526
# {'auc': 0.4523809523809524, 'recall': 0.42857142857142855, 'precision': 0.08333333333333333, 'accuracy': 0.4714285714285714, 'f1': 0.13953488372093023}
# target shape is <unknown> logits shape is (?, 2)
# At epoch155 loss: 59.87506
# {'auc': 0.3461538461538462, 'recall': 0.2, 'precision': 0.029411764705882353, 'accuracy': 0.4714285714285714, 'f1': 0.05128205128205128}
# target shape is <unknown> logits shape is (?, 2)
# At epoch156 loss: 59.86892
# {'auc': 0.3307692307692308, 'recall': 0.2, 'precision': 0.027777777777777776, 'accuracy': 0.44285714285714284, 'f1': 0.048780487804878044}
# target shape is <unknown> logits shape is (?, 2)
# At epoch157 loss: 59.838894
# {'auc': 0.4599271402550091, 'recall': 0.4444444444444444, 'precision': 0.1111111111111111, 'accuracy': 0.4714285714285714, 'f1': 0.17777777777777776}
# target shape is <unknown> logits shape is (?, 2)
# At epoch158 loss: 59.84868
# {'auc': 0.5793650793650794, 'recall': 0.7142857142857143, 'precision': 0.125, 'accuracy': 0.4714285714285714, 'f1': 0.2127659574468085}
# target shape is <unknown> logits shape is (?, 2)
# At epoch159 loss: 59.657707
# {'auc': 0.3307692307692308, 'recall': 0.2, 'precision': 0.027777777777777776, 'accuracy': 0.44285714285714284, 'f1': 0.048780487804878044}
# target shape is <unknown> logits shape is (?, 2)
# At epoch160 loss: 59.699314
# {'auc': 0.6401515151515151, 'recall': 0.75, 'precision': 0.08823529411764706, 'accuracy': 0.5428571428571428, 'f1': 0.15789473684210525}
# target shape is <unknown> logits shape is (?, 2)
# At epoch161 loss: 59.785892
# {'auc': 0.6744791666666667, 'recall': 0.8333333333333334, 'precision': 0.1388888888888889, 'accuracy': 0.5428571428571428, 'f1': 0.2380952380952381}
# target shape is <unknown> logits shape is (?, 2)
# At epoch162 loss: 59.751236
# {'auc': 0.523076923076923, 'recall': 0.6, 'precision': 0.07692307692307693, 'accuracy': 0.45714285714285713, 'f1': 0.13636363636363635}
# target shape is <unknown> logits shape is (?, 2)
# At epoch163 loss: 59.66797
# {'auc': 0.5238095238095237, 'recall': 0.5714285714285714, 'precision': 0.10810810810810811, 'accuracy': 0.4857142857142857, 'f1': 0.18181818181818182}
# target shape is <unknown> logits shape is (?, 2)
# At epoch164 loss: 59.64581
# {'auc': 0.5461538461538462, 'recall': 0.6, 'precision': 0.08333333333333333, 'accuracy': 0.5, 'f1': 0.14634146341463414}
# target shape is <unknown> logits shape is (?, 2)
# At epoch165 loss: 59.63632
# {'auc': 0.5072859744990893, 'recall': 0.5555555555555556, 'precision': 0.13157894736842105, 'accuracy': 0.4714285714285714, 'f1': 0.2127659574468085}
# target shape is <unknown> logits shape is (?, 2)
# At epoch166 loss: 59.56357
# {'auc': 0.6022727272727273, 'recall': 0.75, 'precision': 0.07692307692307693, 'accuracy': 0.4714285714285714, 'f1': 0.13953488372093026}
# target shape is <unknown> logits shape is (?, 2)
# At epoch167 loss: 59.645462
# {'auc': 0.4444444444444444, 'recall': 0.42857142857142855, 'precision': 0.08108108108108109, 'accuracy': 0.45714285714285713, 'f1': 0.13636363636363638}
# target shape is <unknown> logits shape is (?, 2)
# At epoch168 loss: 59.540268
# {'auc': 0.3307692307692308, 'recall': 0.2, 'precision': 0.027777777777777776, 'accuracy': 0.44285714285714284, 'f1': 0.048780487804878044}
# target shape is <unknown> logits shape is (?, 2)
# At epoch169 loss: 59.564404
# {'auc': 0.4984591679506934, 'recall': 0.45454545454545453, 'precision': 0.15625, 'accuracy': 0.5285714285714286, 'f1': 0.2325581395348837}
# target shape is <unknown> logits shape is (?, 2)
# At epoch170 loss: 59.4076
# {'auc': 0.5075757575757576, 'recall': 0.5, 'precision': 0.058823529411764705, 'accuracy': 0.5142857142857142, 'f1': 0.10526315789473684}
# target shape is <unknown> logits shape is (?, 2)
# At epoch171 loss: 59.624332
# {'auc': 0.5705645161290323, 'recall': 0.625, 'precision': 0.14285714285714285, 'accuracy': 0.5285714285714286, 'f1': 0.23255813953488372}
# target shape is <unknown> logits shape is (?, 2)
# At epoch172 loss: 59.299732
# {'auc': 0.37760416666666663, 'recall': 0.3333333333333333, 'precision': 0.05128205128205128, 'accuracy': 0.4142857142857143, 'f1': 0.08888888888888889}
# target shape is <unknown> logits shape is (?, 2)
# At epoch173 loss: 59.39995
# {'auc': 0.365079365079365, 'recall': 0.2857142857142857, 'precision': 0.05405405405405406, 'accuracy': 0.42857142857142855, 'f1': 0.09090909090909091}
# target shape is <unknown> logits shape is (?, 2)
# At epoch174 loss: 59.419224
# {'auc': 0.575, 'recall': 0.7, 'precision': 0.175, 'accuracy': 0.4857142857142857, 'f1': 0.27999999999999997}
# target shape is <unknown> logits shape is (?, 2)
# At epoch175 loss: 59.189484
# {'auc': 0.572139303482587, 'recall': 0.6666666666666666, 'precision': 0.05405405405405406, 'accuracy': 0.4857142857142857, 'f1': 0.1}
# target shape is <unknown> logits shape is (?, 2)
# At epoch176 loss: 59.30842
# {'auc': 0.22307692307692306, 'recall': 0.0, 'precision': 0.0, 'accuracy': 0.4142857142857143, 'f1': 0.0}
# target shape is <unknown> logits shape is (?, 2)
# At epoch177 loss: 59.34354
# {'auc': 0.5, 'recall': 0.5, 'precision': 0.11428571428571428, 'accuracy': 0.5, 'f1': 0.18604651162790695}
# target shape is <unknown> logits shape is (?, 2)
# At epoch178 loss: 59.230145
# {'auc': 0.4765625, 'recall': 0.5, 'precision': 0.07894736842105263, 'accuracy': 0.45714285714285713, 'f1': 0.13636363636363635}
# target shape is <unknown> logits shape is (?, 2)
# At epoch179 loss: 59.22892
# {'auc': 0.4772727272727273, 'recall': 0.5, 'precision': 0.05263157894736842, 'accuracy': 0.45714285714285713, 'f1': 0.09523809523809525}
# target shape is <unknown> logits shape is (?, 2)
# At epoch180 loss: 59.108208
# {'auc': 0.32196969696969696, 'recall': 0.25, 'precision': 0.024390243902439025, 'accuracy': 0.38571428571428573, 'f1': 0.04444444444444444}
# target shape is <unknown> logits shape is (?, 2)
# At epoch181 loss: 59.220535
# {'auc': 0.5793650793650794, 'recall': 0.7142857142857143, 'precision': 0.125, 'accuracy': 0.4714285714285714, 'f1': 0.2127659574468085}
# target shape is <unknown> logits shape is (?, 2)
# At epoch182 loss: 59.033134
# {'auc': 0.48484848484848486, 'recall': 0.5, 'precision': 0.05405405405405406, 'accuracy': 0.4714285714285714, 'f1': 0.0975609756097561}
# target shape is <unknown> logits shape is (?, 2)
# At epoch183 loss: 59.054382
# {'auc': 0.373015873015873, 'recall': 0.2857142857142857, 'precision': 0.05555555555555555, 'accuracy': 0.44285714285714284, 'f1': 0.09302325581395349}
# target shape is <unknown> logits shape is (?, 2)
# At epoch184 loss: 58.905952
# {'auc': 0.4779411764705882, 'recall': 0.5, 'precision': 0.02631578947368421, 'accuracy': 0.45714285714285713, 'f1': 0.05}
# target shape is <unknown> logits shape is (?, 2)
# At epoch185 loss: 59.090443
# {'auc': 0.689516129032258, 'recall': 0.75, 'precision': 0.20689655172413793, 'accuracy': 0.6428571428571429, 'f1': 0.32432432432432434}
# target shape is <unknown> logits shape is (?, 2)
# At epoch186 loss: 58.95072
# {'auc': 0.6325757575757576, 'recall': 0.75, 'precision': 0.08571428571428572, 'accuracy': 0.5285714285714286, 'f1': 0.15384615384615383}
# target shape is <unknown> logits shape is (?, 2)
# At epoch187 loss: 58.930363
# {'auc': 0.6401515151515151, 'recall': 0.75, 'precision': 0.08823529411764706, 'accuracy': 0.5428571428571428, 'f1': 0.15789473684210525}
# target shape is <unknown> logits shape is (?, 2)
# At epoch188 loss: 58.87481
# {'auc': 0.2537313432835821, 'recall': 0.0, 'precision': 0.0, 'accuracy': 0.4857142857142857, 'f1': 0.0}
# target shape is <unknown> logits shape is (?, 2)
# At epoch189 loss: 58.874065
# {'auc': 0.7352941176470589, 'recall': 1.0, 'precision': 0.05263157894736842, 'accuracy': 0.4857142857142857, 'f1': 0.1}
# target shape is <unknown> logits shape is (?, 2)
# At epoch190 loss: 58.887955
# {'auc': 0.41538461538461535, 'recall': 0.4, 'precision': 0.05128205128205128, 'accuracy': 0.42857142857142855, 'f1': 0.09090909090909091}
# target shape is <unknown> logits shape is (?, 2)
# At epoch191 loss: 58.89693
# {'auc': 0.4920634920634921, 'recall': 0.5714285714285714, 'precision': 0.0975609756097561, 'accuracy': 0.42857142857142855, 'f1': 0.16666666666666669}
# target shape is <unknown> logits shape is (?, 2)
# At epoch192 loss: 58.786785
# {'auc': 0.3968253968253968, 'recall': 0.2857142857142857, 'precision': 0.06060606060606061, 'accuracy': 0.4857142857142857, 'f1': 0.1}
# target shape is <unknown> logits shape is (?, 2)
# At epoch193 loss: 58.773685
# {'auc': 0.6510416666666667, 'recall': 0.8333333333333334, 'precision': 0.1282051282051282, 'accuracy': 0.5, 'f1': 0.2222222222222222}
# target shape is <unknown> logits shape is (?, 2)
# At epoch194 loss: 58.755714
# {'auc': 0.4375, 'recall': 0.375, 'precision': 0.08823529411764706, 'accuracy': 0.4857142857142857, 'f1': 0.14285714285714285}
# target shape is <unknown> logits shape is (?, 2)
# At epoch195 loss: 58.79084
# {'auc': 0.5221774193548387, 'recall': 0.625, 'precision': 0.12195121951219512, 'accuracy': 0.44285714285714284, 'f1': 0.20408163265306123}
# target shape is <unknown> logits shape is (?, 2)
# At epoch196 loss: 58.856514
# {'auc': 0.5546448087431695, 'recall': 0.6666666666666666, 'precision': 0.15, 'accuracy': 0.4714285714285714, 'f1': 0.24489795918367346}
# target shape is <unknown> logits shape is (?, 2)
# At epoch197 loss: 58.6549
# {'auc': 0.49242424242424243, 'recall': 0.5, 'precision': 0.05555555555555555, 'accuracy': 0.4857142857142857, 'f1': 0.09999999999999999}
# target shape is <unknown> logits shape is (?, 2)
# At epoch198 loss: 58.673157
# {'auc': 0.6020036429872495, 'recall': 0.7777777777777778, 'precision': 0.16666666666666666, 'accuracy': 0.4714285714285714, 'f1': 0.2745098039215686}
# target shape is <unknown> logits shape is (?, 2)
# At epoch199 loss: 58.684834
# {'auc': 0.405241935483871, 'recall': 0.375, 'precision': 0.07894736842105263, 'accuracy': 0.42857142857142855, 'f1': 0.13043478260869565}
# target shape is <unknown> logits shape is (?, 2)
# At the end loss: 58.475273
# {'auc': 0.21323529411764708, 'recall': 0.0, 'precision': 0.0, 'accuracy': 0.4142857142857143, 'f1': 0.0}
